# %% [markdown]
# ### Speed Dating Dataset EDA:
# ### The following analysis is being done as a mandatory project for certification bloc 2 (Machine Learning Engineer at Jedha).

# %% [markdown]
# ### 1. Importing necessary libraries

# %%
import pandas as pd
pd.options.display.max_rows = 999
pd.set_option('display.max_columns', None)
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px
import plotly.graph_objs as go
import plotly.tools as tls
from plotly.subplots import make_subplots
import plotly.io as pio
from IPython.display import Image

# %% [markdown]
# ### 2. Importing the dataset and running some preliminary statistical analysis

# %%
df=pd.read_csv("Speed_Dating_Data.csv", encoding="latin1")
display(df.head(5))
# Out:
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4
# 1    1  1.0       0    1       1     1     10         7       NaN      3
# 2    1  1.0       0    1       1     1     10         7       NaN     10
# 3    1  1.0       0    1       1     1     10         7       NaN      5
# 4    1  1.0       0    1       1     1     10         7       NaN      7
#
#    partner   pid  match  int_corr  samerace  age_o  race_o  pf_o_att  \
# 0        1  11.0      0      0.14         0   27.0     2.0      35.0
# 1        2  12.0      0      0.54         0   22.0     2.0      60.0
# 2        3  13.0      1      0.16         1   22.0     4.0      19.0
# 3        4  14.0      1      0.61         0   23.0     2.0      30.0
# 4        5  15.0      1      0.21         0   24.0     3.0      30.0
#
#    pf_o_sin  pf_o_int  pf_o_fun  pf_o_amb  pf_o_sha  dec_o  attr_o  sinc_o  \
# ...

# %%
df.columns
# Out:
# Index(['iid', 'id', 'gender', 'idg', 'condtn', 'wave', 'round', 'position',
#        'positin1', 'order',
#        ...
#        'attr3_3', 'sinc3_3', 'intel3_3', 'fun3_3', 'amb3_3', 'attr5_3',
#        'sinc5_3', 'intel5_3', 'fun5_3', 'amb5_3'],
#       dtype='object', length=195)

# %%
df.shape
# Out:
# (8378, 195)

# %%
display(df.tail(2))
# Out:
#       iid    id  gender  idg  condtn  wave  round  position  positin1  order  \
# 8376  552  22.0       1   44       2    21     22         3      10.0     16
# 8377  552   NaN       1   44       2    21     22         2      10.0     15
#
#       partner    pid  match  int_corr  samerace  age_o  race_o  pf_o_att  \
# 8376       21  529.0      0      0.62         0   22.0     4.0      10.0
# 8377       22  530.0      0      0.01         0   22.0     4.0      20.0
#
#       pf_o_sin  pf_o_int  pf_o_fun  pf_o_amb  pf_o_sha  dec_o  attr_o  sinc_o  \
# 8376      25.0      25.0      10.0      10.0      20.0      1     5.0     7.0
# 8377      20.0      10.0      15.0       5.0      30.0      1     8.0     8.0
#
#       intel_o  fun_o  amb_o  shar_o  like_o  prob_o  met_o   age  \
# 8376      5.0    5.0    3.0     6.0     6.0     4.0    2.0  25.0
# 8377      7.0    7.0    7.0     7.0     8.0     5.0    2.0  25.0
#
# ...

# %%
df.describe()
# Out:
#                iid           id       gender          idg       condtn  \
# count  8378.000000  8377.000000  8378.000000  8378.000000  8378.000000
# mean    283.675937     8.960248     0.500597    17.327166     1.828837
# std     158.583367     5.491329     0.500029    10.940735     0.376673
# min       1.000000     1.000000     0.000000     1.000000     1.000000
# 25%     154.000000     4.000000     0.000000     8.000000     2.000000
# 50%     281.000000     8.000000     1.000000    16.000000     2.000000
# 75%     407.000000    13.000000     1.000000    26.000000     2.000000
# max     552.000000    22.000000     1.000000    44.000000     2.000000
#
#               wave        round     position     positin1        order  \
# count  8378.000000  8378.000000  8378.000000  6532.000000  8378.000000
# mean     11.350919    16.872046     9.042731     9.295775     8.927668
# std       5.995903     4.358458     5.514939     5.650199     5.477009
# ...

# %% [markdown]
# ### 3. Verification of missing values

# %%
# Checking for missing values
display(df.isna().sum())
# Out:
# iid            0
# id             1
# gender         0
# idg            0
# condtn         0
# wave           0
# round          0
# position       0
# positin1    1846
# order          0
# partner        0
# pid           10
# match          0
# int_corr     158
# samerace       0
# age_o        104
# race_o        73
# pf_o_att      89
# pf_o_sin      89
# pf_o_int      89
# pf_o_fun      98
# pf_o_amb     107
# pf_o_sha     129
# dec_o          0
# attr_o       212
# sinc_o       287
# intel_o      306
# fun_o        360
# amb_o        722
# shar_o      1076
# like_o       250
# prob_o       318
# met_o        385
# age           95
# field         63
# field_cd      82
# undergra    3464
# mn_sat      5245
# tuition     4795
# race          63
# imprace       79
# imprelig      79
# from          79
# zipcode     1064
# income      4099
# goal          79
# date          97
# go_out        79
# career        89
# career_c     138
# sports        79
# tvsports      79
# ...

# %%
# Visualizing missing values with Seaborn
missing_values = df.isnull().sum()
missing_percent = (missing_values / len(df)) * 100

plt.figure(figsize=(12, 6))
missing_percent[missing_percent > 60].sort_values().plot(kind="barh", color="coral")

plt.xlabel("Percentage of Missing Values")
plt.ylabel("Columns")
plt.title("Missing Data Overview")

# Adjust label formatting
plt.xticks(fontsize=12)  # Change font size of x-axis
plt.yticks(fontsize=10, rotation=0)  # Make y-axis text readable
plt.tight_layout()  # Adjust spacing to prevent overlap

plt.show()

# %%
# Drop columns where missing values > 30%
threshold = 0.3 # 30% missing data threshold
df_1 = df.loc[:, df.isnull().mean() < threshold]
missing_percent = df.isnull().mean()
dropped_cols = missing_percent[missing_percent > threshold].index
print("Dropped Columns:", list(dropped_cols))
print(len(dropped_cols))
# Out:
# Dropped Columns: ['undergra', 'mn_sat', 'tuition', 'income', 'expnum', 'attr5_1', 'sinc5_1', 'intel5_1', 'fun5_1', 'amb5_1', 'attr1_s', 'sinc1_s', 'intel1_s', 'fun1_s', 'amb1_s', 'shar1_s', 'attr3_s', 'sinc3_s', 'intel3_s', 'fun3_s', 'amb3_s', 'attr7_2', 'sinc7_2', 'intel7_2', 'fun7_2', 'amb7_2', 'shar7_2', 'attr4_2', 'sinc4_2', 'intel4_2', 'fun4_2', 'amb4_2', 'shar4_2', 'attr2_2', 'sinc2_2', 'intel2_2', 'fun2_2', 'amb2_2', 'shar2_2', 'attr5_2', 'sinc5_2', 'intel5_2', 'fun5_2', 'amb5_2', 'you_call', 'them_cal', 'date_3', 'numdat_3', 'num_in_3', 'attr1_3', 'sinc1_3', 'intel1_3', 'fun1_3', 'amb1_3', 'shar1_3', 'attr7_3', 'sinc7_3', 'intel7_3', 'fun7_3', 'amb7_3', 'shar7_3', 'attr4_3', 'sinc4_3', 'intel4_3', 'fun4_3', 'amb4_3', 'shar4_3', 'attr2_3', 'sinc2_3', 'intel2_3', 'fun2_3', 'amb2_3', 'shar2_3', 'attr3_3', 'sinc3_3', 'intel3_3', 'fun3_3', 'amb3_3', 'attr5_3', 'sinc5_3', 'intel5_3', 'fun5_3', 'amb5_3']
# 83

# %% [markdown]
# <span style="font-size:14px;"> The missing values analysis shows that most of the data missing concerns the columns with the follow up data collected from participants after the speed dating event, ie at the "Time 2" (the day after the event) and "Time 3" (3-4 weeks after the event), like for example: numdat_3. If we consider columns where these missing values exceed 40%, the data is reduced by 71 columns. Therefore the further analysis of this follow up doesn't seem representative for the group of participants analysed. It would be more judicious to focus on the data gathered before and during the event to understand the composition of the group, their reasons to participate as well as the features that lead the participants to get a "match" with a participant of the opposite sex.</span>

# %%
# Checking the number of columns after dropping those with over 30% of the values missing
df_1.shape
# Out:
# (8378, 112)

# %%
# Checking for the missing values in the remaining columns
display(df_1.isna().sum())
# Out:
# iid            0
# id             1
# gender         0
# idg            0
# condtn         0
# wave           0
# round          0
# position       0
# positin1    1846
# order          0
# partner        0
# pid           10
# match          0
# int_corr     158
# samerace       0
# age_o        104
# race_o        73
# pf_o_att      89
# pf_o_sin      89
# pf_o_int      89
# pf_o_fun      98
# pf_o_amb     107
# pf_o_sha     129
# dec_o          0
# attr_o       212
# sinc_o       287
# intel_o      306
# fun_o        360
# amb_o        722
# shar_o      1076
# like_o       250
# prob_o       318
# met_o        385
# age           95
# field         63
# field_cd      82
# race          63
# imprace       79
# imprelig      79
# from          79
# zipcode     1064
# goal          79
# date          97
# go_out        79
# career        89
# career_c     138
# sports        79
# tvsports      79
# exercise      79
# dining        79
# museums       79
# art           79
# ...

# %%
print(df_1.select_dtypes(include=['number']).columns)
# Out:
# Index(['iid', 'id', 'gender', 'idg', 'condtn', 'wave', 'round', 'position',
#        'positin1', 'order',
#        ...
#        'sinc1_2', 'intel1_2', 'fun1_2', 'amb1_2', 'shar1_2', 'attr3_2',
#        'sinc3_2', 'intel3_2', 'fun3_2', 'amb3_2'],
#       dtype='object', length=108)

# %%
# Replacing the missing numeric values with the median values
df_1.loc[:, df_1.select_dtypes(include=['number']).columns] = df_1.select_dtypes(include=['number']).apply(lambda x: x.fillna(x.median()))

# %%
display(df_1.isna().sum())
# Out:
# iid            0
# id             0
# gender         0
# idg            0
# condtn         0
# wave           0
# round          0
# position       0
# positin1       0
# order          0
# partner        0
# pid            0
# match          0
# int_corr       0
# samerace       0
# age_o          0
# race_o         0
# pf_o_att       0
# pf_o_sin       0
# pf_o_int       0
# pf_o_fun       0
# pf_o_amb       0
# pf_o_sha       0
# dec_o          0
# attr_o         0
# sinc_o         0
# intel_o        0
# fun_o          0
# amb_o          0
# shar_o         0
# like_o         0
# prob_o         0
# met_o          0
# age            0
# field         63
# field_cd       0
# race           0
# imprace        0
# imprelig       0
# from          79
# zipcode     1064
# goal           0
# date           0
# go_out         0
# career        89
# career_c       0
# sports         0
# tvsports       0
# exercise       0
# dining         0
# museums        0
# art            0
# ...

# %% [markdown]
# ### 4. Zoom at the composition and origin of participants

# %%
# Checking the exact number of participants
display(len(df_1["iid"].unique()))
# Out:
# 551

# %%
# Grouping the "gender" unique by "iid" unique gives the exact number of men and women participating in the event
df_1.groupby("gender")["iid"].nunique()
# Out:
# gender
# 0    274
# 1    277
# Name: iid, dtype: int64

# %%
# # Grouping the "gender" unique by value counts gives the  number of men and women participating in rounds; 
# however all of them participate is many rounds so they are all counted several times
display(df_1.gender.value_counts())
# Out:
# gender
# 1    4194
# 0    4184
# Name: count, dtype: int64

# %%
df_1.loc[:, df_1.select_dtypes(include=['number']).columns]

# %%
# For more understandable plotting, changing the type of data in the "gender" column
df_1.loc[:,'Gender']=df_1['gender'].apply(lambda x: "Women" if x==0 else
                                "Men" )

# %%
# Graphical representation of distribution by "Gender" with Plotly Express
fig = px.histogram(df_1, x="Gender", color="Gender", title="Gender distribution")
fig.show()

# %%
# Graphical representation of distribution by "Gender" with Seaborn
# Set figure size
plt.figure(figsize=(8,5))

# Plot gender distribution using Seaborn
sns.countplot(data=df_1, x="Gender", hue="Gender", legend=True, palette="coolwarm")

# Add title & labels
plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Count")

# Show the plot
plt.show()

# %%
# Looking closer at the average age of participants with distinction by gender
df_1.groupby("Gender")["age"].mean()
# Out:
# Gender
# Men      26.604912
# Women    26.104207
# Name: age, dtype: float64

# %%
# Plot Age Distribution with Plotly Express
fig = px.histogram(df_1, x="age", color="gender", title="Age distribution")
fig.show()

# %%
# Plot Age Distribution with Seaborn
sns.histplot(df_1['age'], bins=20, kde=True, color='skyblue')
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# <span style="font-size:14px;"> The above analysis shows that the average age of participants is 26 years old and it varies mostly between 20 and 35 years olds.</span>

# %%
df_1.loc[:, df_1.select_dtypes(include=['number']).columns]

# %%
# Let's have a look at the origin of participants. For better understandig, changing the column names.
df_1.loc[:, 'race'] = df_1['race'].apply(lambda x:  "Black/African American" if x == 1 else
                                     "European/Caucasian-American" if x == 2 else
                                     "Latino/Hispanic American" if x == 3 else
                                     "Asian/Pacific Islander/Asian-American" if x == 4 else
                                     "Native American" if x == 5 else
                                     "other" if x == 6 else
                                     "no data")
# Out:
# C:\Users\aheij\AppData\Local\Temp\ipykernel_21280\1209946881.py:2: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['Asian/Pacific Islander/Asian-American'
#  'Asian/Pacific Islander/Asian-American'
#  'Asian/Pacific Islander/Asian-American' ... 'European/Caucasian-American'
#  'European/Caucasian-American' 'European/Caucasian-American']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.

# %%
df_1['race'].unique()
df_1['race'].value_counts()
# Out:
# race
# European/Caucasian-American              4790
# Asian/Pacific Islander/Asian-American    1982
# Latino/Hispanic American                  664
# other                                     522
# Black/African American                    420
# Name: count, dtype: int64

# %%
# Create a histogram for race distribution
fig = px.histogram(
    df_1, 
    x='race',
    color='race',  # Coloring by race category
    title='Distribution of Participants by Race',
    labels={'race': 'Race', 'count': 'Number of Participants'},
    text_auto=True  # Adds count labels on top of bars
)

# Customize the layout
fig.update_layout(
    xaxis_title='Race',
    yaxis_title='Number of Participants',
    bargap=0.2,  # Gap between bars
    showlegend=False  # Hide legend since color and x-axis show the same info
)

# Display the figure
fig.show()

# %%
# Generate a histogram with with Plotly Express
fig = px.histogram(df_1, x="race", color="Gender", title="Gender and race distribution")
fig.show()

# %%
# Looking at the intended goal of the participants
# recoding goal variable from int to string
df_1.loc[:, 'goal'] = df_1.goal.apply(lambda x: "fun night out" if x == 1 else
                                    "meet new people" if x == 2 else
                                    "get a date" if x == 3 else
                                    "looking for serious relationship" if x == 4 else 
                                    "to say I dit it" if x == 5 else  
                                    "other goal" if x == 6 else
                                    "no data")
# Out:
# C:\Users\aheij\AppData\Local\Temp\ipykernel_21280\3514977676.py:3: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['meet new people' 'meet new people' 'meet new people' ... 'fun night out'
#  'fun night out' 'fun night out']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.

# %%
df_1['goal'].unique()
# Out:
# array(['meet new people', 'fun night out', 'other goal', 'get a date',
#        'looking for serious relationship', 'to say I dit it'],
#       dtype=object)

# %%
fig = px.histogram(df_1, x="goal", color="Gender", category_orders=dict(goal=['meet new people', 'fun night out', 'other goal', 'get a date',
       'looking for serious relationship','to say I dit it']), title="Why do people participate in Speed dating?")
fig.show()

# %% [markdown]
# ### Does the origin or the goal of participating in the speed dating event influence getting a "match"?

# %%
# First, let's have a look at the relation of the origin (race) and getting a "match"
df_1.groupby("samerace")["match"].mean()
# Out:
# samerace
# 0    0.160806
# 1    0.170688
# Name: match, dtype: float64

# %%
# Visualizing with Plotly Express the relation between the race similarity and getting a match
match_rates = df_1.groupby("samerace")["match"].mean().reset_index()
match_rates["samerace"] = match_rates["samerace"].map({0: "Different Race", 1: "Same Race"})

fig = px.bar(match_rates, x="samerace", y="match", title="Does Race Similarity Affect Getting a Match?",
             labels={"match": "Match Rate", "samerace": "Race Similarity"}, text_auto=True)
fig.show()

# %% [markdown]
# <span style="font-size:14px;"> Conclusion: the origin of participants does not significantly influence getting a "match".</span>

# %%
# Let's have a look which of the intended goals of participation influences most getting a match?
df_1.groupby("goal")["match"].mean()
# Out:
# goal
# fun night out                       0.170169
# get a date                          0.158479
# looking for serious relationship    0.169435
# meet new people                     0.161436
# other goal                          0.147971
# to say I dit it                     0.166667
# Name: match, dtype: float64

# %%
# Visualization with Plotly Express
match_rates = df_1.groupby("goal")["match"].mean().reset_index()
# Replace numerical values with descriptive labels
match_rates["goal"] = match_rates["goal"].replace({
    1: "Fun night out",
    2: "Meet new people",
    3: "Get a date",
    4: "Looking for serious relationship",
    5: "To say I did it",
    6: "Other goal"
})

# Create bar chart
fig = px.bar(match_rates, x="goal", y="match", title="Does the Intended Goal Affect Getting a Match?",
             labels={"match": "Match Rate", "goal": "Goal"}, text_auto=True)

fig.show()

# %% [markdown]
# <span style="font-size:14px;"> Conclusion: the strong motivation to meet new people seems to result in the highest match rate comparing to other intended goals of participation in the speed dating event.</span>

# %% [markdown]
# ### Let's look at the matches obtained by participants : how gets most of them?

# %%
df_1.groupby(["Gender"])["match"].mean()
# Out:
# Gender
# Men      0.164521
# Women    0.164914
# Name: match, dtype: float64

# %%
df_1.groupby(["age"])["match"].mean()
# Out:
# age
# 18.0    0.000000
# 19.0    0.250000
# 20.0    0.254545
# 21.0    0.223368
# 22.0    0.143511
# 23.0    0.161074
# 24.0    0.142526
# 25.0    0.234170
# 26.0    0.170124
# 27.0    0.158640
# 28.0    0.174263
# 29.0    0.157895
# 30.0    0.144599
# 31.0    0.144000
# 32.0    0.100000
# 33.0    0.124224
# 34.0    0.131579
# 35.0    0.166667
# 36.0    0.088889
# 37.0    0.000000
# 38.0    0.105263
# 39.0    0.111111
# 42.0    0.200000
# 55.0    0.000000
# Name: match, dtype: float64

# %%
df_1.groupby(["Gender", "age"])["match"].mean()
# Out:
# Gender  age
# Men     18.0    0.000000
#         19.0    0.000000
#         20.0    0.120000
#         21.0    0.277778
#         22.0    0.127148
#         23.0    0.175711
#         24.0    0.149144
#         25.0    0.227749
#         26.0    0.174447
#         27.0    0.160194
#         28.0    0.188372
#         29.0    0.154696
#         30.0    0.157025
#         31.0    0.070423
#         32.0    0.104575
#         33.0    0.111111
#         34.0    0.115942
#         36.0    0.050000
#         37.0    0.000000
#         39.0    0.111111
#         42.0    0.200000
# Women   19.0    0.500000
#         20.0    0.366667
#         21.0    0.191257
#         22.0    0.156593
#         23.0    0.149901
#         24.0    0.136564
#         25.0    0.239560
#         26.0    0.166966
#         27.0    0.156463
#         28.0    0.155063
#         29.0    0.162996
#         30.0    0.123223
#         31.0    0.240741
#         32.0    0.087719
#         33.0    0.128000
# ...

# %%
# Compute match rates by gender & age
match_rates = df_1.groupby(["gender", "age"])["match"].mean().reset_index()

# Convert gender labels (if needed)
match_rates["gender"] = match_rates["gender"].map({0: "Female", 1: "Male"})

# Create bar chart
fig = px.bar(match_rates, x="age", y="match", color="gender",
             barmode="group", title="Match Rates by Gender and Age",
             labels={"match": "Match Rate", "age": "Age", "gender": "Gender"},
             text_auto=True)
fig.show()

# %% [markdown]
# ### What attributes do participants look for in the opposite sex? What attribute is the most/the least desirable ?

# %%
# Renaming personal attributes that participants look for in their partners to more clear names

attributes = df_1[['attr1_1', 'sinc1_1','intel1_1','fun1_1','amb1_1','shar1_1']]
attributes.columns = ['Attractive', 'Sincere','Intelligent','Fun','Ambitious','Shared_interests']

attributes_sort = attributes.mean().sort_values(ascending=False)
attributes_sort
# Out:
# Attractive          22.490920
# Intelligent         20.263108
# Fun                 17.462811
# Sincere             17.403778
# Shared_interests    11.827706
# Ambitious           10.674474
# dtype: float64

# %%
df_1.groupby("Gender")[['attr1_1', 'sinc1_1','intel1_1','fun1_1','amb1_1','shar1_1']].mean()
# Out:
#           attr1_1    sinc1_1   intel1_1     fun1_1     amb1_1    shar1_1
# Gender
# Men     26.888681  16.506454  19.539580  17.765582   8.566631  10.993174
# Women   18.082648  18.303246  20.988365  17.159316  12.787354  12.664233

# %%
mean_preferences = df_1.groupby("Gender")[["attr1_1", "sinc1_1", "intel1_1", "fun1_1", "amb1_1", "shar1_1"]].mean()

# %%
mean_preferences.T.sort_values(by=["Women", "Men"], ascending=True)
# Out:
# Gender          Men      Women
# shar1_1   10.993174  12.664233
# amb1_1     8.566631  12.787354
# fun1_1    17.765582  17.159316
# attr1_1   26.888681  18.082648
# sinc1_1   16.506454  18.303246
# intel1_1  19.539580  20.988365

# %%
# Transform data for better plotting
df_sorted = mean_preferences.T.reset_index().melt(id_vars="index", var_name="Gender", value_name="Mean Score")

# Create bar chart
fig = px.bar(df_sorted, x="index", y="Mean Score", color="Gender",
             title="Average Partner Preferences by Gender", 
             barmode="group", text_auto=True)
fig.update_layout(xaxis_title="Attributes", yaxis_title="Mean Score")
fig.show()

# %% [markdown]
# <span style="font-size:14px;"> Conclusion: Men look mostly for attractive women in speed dating (shared interests or ambitions don't seem to bother them too much) whereas women focus rather on intelligence and sincerity however the attractiveness is also rather important.</span>

# %% [markdown]
# <span style="font-size:14px;"> Next point to check would be the attribute that most of participants think that the opposite sex is looking for.</span>

# %%
# Renaming personal attributes that participants think the opposite sex looks for in their partners
guess_of_pref_attributes = df_1[['attr4_1', 'sinc4_1','intel4_1','fun4_1','amb4_1','shar4_1']]
guess_of_pref_attributes.columns = ['Attractive', 'Sincere','Intelligent','Fun','Ambitious','Shared_interests']

guess_of_pref_attributes_sort = guess_of_pref_attributes.mean().sort_values(ascending=False)
guess_of_pref_attributes_sort
# Out:
# Attractive          26.079971
# Fun                 15.439007
# Intelligent         12.041895
# Sincere             10.829912
# Shared_interests    10.783361
# Ambitious            9.829673
# dtype: float64

# %%
df_1.groupby("Gender")[['attr4_1', 'sinc4_1','intel4_1','fun4_1','amb4_1','shar4_1']].mean()
# Out:
#           attr4_1    sinc4_1   intel4_1     fun4_1     amb4_1    shar4_1
# Gender
# Men     27.380544  10.599189  11.674773  15.932046   8.212208  10.674535
# Women   24.776291  11.061185  12.409895  14.944790  11.451004  10.892447

# %%
mean_guessed_preferences = df_1.groupby("Gender")[["attr4_1", "sinc4_1", "intel4_1", "fun4_1", "amb4_1", "shar4_1"]].mean()

# %%
mean_guessed_preferences.T.sort_values(by=["Women", "Men"], ascending=True)
# Out:
# Gender          Men      Women
# shar4_1   10.674535  10.892447
# sinc4_1   10.599189  11.061185
# amb4_1     8.212208  11.451004
# intel4_1  11.674773  12.409895
# fun4_1    15.932046  14.944790
# attr4_1   27.380544  24.776291

# %%
# Transform data for better plotting
df_sorted = mean_guessed_preferences.T.reset_index().melt(id_vars="index", var_name="Gender", value_name="Mean Score")

# Create bar chart
fig = px.bar(df_sorted, x="index", y="Mean Score", color="Gender",
             title="Average Partner Guessed Preferences by Gender", 
             barmode="group", text_auto=True)
fig.update_layout(xaxis_title="Attributes", yaxis_title="Mean Score")
fig.show()

# %% [markdown]
# <span style="font-size:14px;"> Conclusion: Both women and men think that the opposite sex looks for an attractive and fun partner.</span>

# %% [markdown]
# ### Let's see what is more decisive for the participants between the same racial backgroud and shared interests.

# %%
# Comparison of the importance attributed to the same racial background (imprace) vs shared interests (shar1_1)

imprace_vs_shar1_1 = df_1[['imprace','shar4_1']]
imprace_vs_shar1_1.columns = ['Importance of the same ethnic background','Shared_interests']

imprace_vs_shar1_1_sort = imprace_vs_shar1_1.mean().sort_values(ascending=False)
imprace_vs_shar1_1_sort
# Out:
# Shared_interests                            10.783361
# Importance of the same ethnic background     3.777393
# dtype: float64

# %%
df_1.groupby("Gender")[['imprace','shar1_1']].mean()
# Out:
#          imprace    shar1_1
# Gender
# Men     3.462327  10.993174
# Women   4.093212  12.664233

# %%
mean_race_interests = df_1.groupby("Gender")[["imprace", "shar1_1"]].mean()

# %%
mean_race_interests.T.sort_values(by=["Women", "Men"], ascending=True)
# Out:
# Gender         Men      Women
# imprace   3.462327   4.093212
# shar1_1  10.993174  12.664233

# %%
# Transform data for better plotting
df_sorted = mean_race_interests.T.reset_index().melt(id_vars="index", var_name="Gender", value_name="Mean Score")

# Create bar chart
fig = px.bar(df_sorted, x="index", y="Mean Score", color="Gender",
             title="Importance of common origin and shared interests", 
             barmode="group", text_auto=True)
fig.update_layout(xaxis_title="Attributes", yaxis_title="Mean Score")
fig.show()

# %%
# Can people accurately predict their own perceived value in the dating market?
# # Select attributes for self vs. others' evaluation
self_evaluated_attributes = ["attr3_1", "sinc3_1", "intel3_1", "fun3_1", "amb3_1"]
peer_evaluated_attributes = ["attr5_1", "sinc5_1", "intel5_1", "fun5_1", "amb5_1"]

# Compute average scores
self_eval = df[self_evaluated_attributes].mean().values
peer_eval = df[peer_evaluated_attributes].mean().values

# %%
# Organize into a DataFrame
radar_df = pd.DataFrame({
    "Feature": self_evaluated_attributes,  # Labels for the radar axes
    "Self-Evaluation": self_eval,
    "Peer Evaluation": peer_eval
})
radar_df = radar_df.melt(id_vars="Feature", var_name="Evaluation Type", value_name="Score")

# Create Radar Chart
fig = px.line_polar(radar_df, r="Score", theta="Feature", color="Evaluation Type",
                    title="Self-Perception vs. Peer Evaluation in Speed Dating",
                    line_close=True)  # Closing the shape for a web-like effect
fig.show()

# %%
# Group by gender and compute mean
mean_by_gender = df.groupby("gender")[self_evaluated_attributes + peer_evaluated_attributes].mean()

# %%
# Convert male data to long format
male_df = pd.DataFrame({
    "Feature": self_evaluated_attributes, 
    "Self-Evaluation": mean_by_gender.loc["Men", self_evaluated_attributes].values,
    "Peer Evaluation": mean_by_gender.loc["Men", peer_evaluated_attributes].values
}).melt(id_vars="Feature", var_name="Evaluation Type", value_name="Score")

# Convert female data to long format
female_df = pd.DataFrame({
    "Feature": self_evaluated_attributes, 
    "Self-Evaluation": mean_by_gender.loc["Women", self_evaluated_attributes].values,
    "Peer Evaluation": mean_by_gender.loc["Women", peer_evaluated_attributes].values
}).melt(id_vars="Feature", var_name="Evaluation Type", value_name="Score")

# %%
fig_male = px.line_polar(male_df, r="Score", theta="Feature", color="Evaluation Type",
                         title="Self vs. Peer Evaluation (Men)", line_close=True)

fig_female = px.line_polar(female_df, r="Score", theta="Feature", color="Evaluation Type",
                           title="Self vs. Peer Evaluation (Women)", line_close=True)

fig_male.show()
fig_female.show()

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Create the subplot figure with 1 row and 2 columns
fig = make_subplots(rows=1, cols=2, subplot_titles=("Men", "Women"),
                    specs=[[{"type": "polar"}, {"type": "polar"}]])

# Add radar chart for men's self-evaluation (blue)
fig.add_trace(go.Scatterpolar(
    r=male_df.loc[male_df["Evaluation Type"] == "Self-Evaluation", "Score"],
    theta=male_df.loc[male_df["Evaluation Type"] == "Self-Evaluation", "Feature"],
    mode="lines+markers",
    name="Self Evaluation",
    marker=dict(color="blue")
), row=1, col=1)

# Add radar chart for men's peer evaluation (red)
fig.add_trace(go.Scatterpolar(
    r=male_df.loc[male_df["Evaluation Type"] == "Peer Evaluation", "Score"],
    theta=male_df.loc[male_df["Evaluation Type"] == "Peer Evaluation", "Feature"],
    mode="lines+markers",
    name="Peer Evaluation",
    marker=dict(color="red")
), row=1, col=1)

# Add radar chart for women's self-evaluation (blue)
fig.add_trace(go.Scatterpolar(
    r=female_df.loc[female_df["Evaluation Type"] == "Self-Evaluation", "Score"],
    theta=female_df.loc[female_df["Evaluation Type"] == "Self-Evaluation", "Feature"],
    mode="lines+markers",
    name="Self Evaluation",
    marker=dict(color="blue")
), row=1, col=2)

# Add radar chart for women's peer evaluation (red)
fig.add_trace(go.Scatterpolar(
    r=female_df.loc[female_df["Evaluation Type"] == "Peer Evaluation", "Score"],
    theta=female_df.loc[female_df["Evaluation Type"] == "Peer Evaluation", "Feature"],
    mode="lines+markers",
    name="Peer Evaluation",
    marker=dict(color="red")
), row=1, col=2)

# Update layout
fig.update_layout(title_text="Self vs. Peer Evaluation by Gender", showlegend=True, legend_title="Evaluation Type")
fig.show()

# %% [markdown]
# <span style="font-size:14px;"> In terms of getting a second date, is it better to be someone's first speed date of the night or their last?</span>

# %%
# The variables to analyse: date_3 (second date obtained yes = 1/no = 0) and order
print(df['date_3'].unique())
print(df['order'].unique())
print(len(df['order'].unique()))

df.groupby("date_3")["order"].describe()
# Out:
# [ 0. nan  1.]
# [ 4  3 10  5  7  6  1  2  8  9 11 15 12 16 13 14 18 17 19 20 21 22]
# 22
#          count      mean       std  min  25%  50%   75%   max
# date_3
# 0.0     2476.0  8.682149  5.381106  1.0  4.0  8.0  13.0  22.0
# 1.0     1498.0  9.104139  5.472208  1.0  4.0  8.5  13.0  22.0

# %%
fig = px.box(df, x="date_3", y="order", title="Do Later Speed Dates Get More Second Dates?",
             labels={"date_3": "Second Date (1=Yes, 0=No)", "order": "Speed Date Position"})
fig.show()

# %% [markdown]
# ### Final conclusions

# %% [markdown]
# <span style="font-size:14px;"> While speed dating, men look mainly for attractive women, women put most attention to the intelligence in evaluating men. The least desirable attribute for men while looking for a female partner is being ambitious and women put the least attention to shared interests. However, share interests are more important for both men and women than having the same racial background. So as to own value predictions compared to the notes attributed by others, both men and women tend to slightly overestimate certain attributes, like for example being sincere or fun. In terms of getting the second date, it doesn't matter whether you are the first or the last speed date on the night of the event.</span>
